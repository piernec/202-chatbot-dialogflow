# %% [markdown]
# <a href="https://colab.research.google.com/github/piernec/202-chatbot-dialogflow/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
     
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://0d1fbc5b0e2f:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
  dfjoin.show()
# Out:
# +-----------------------+---------------+--------------------+--------------+--------------+-----------------+-----------+-------------------+------------+----------------------+---------+--------------------+---------------------+----------------------+----------------+--------------------+----------+---------+-----------------------+---------------+--------------------+----------------+--------------+-----------------+-----------+-------------------+------------+----------------------+---------+--------------------+---------------------+----------------------+----------------+--------------------+----------+---------+
# ...

# %%
df1 = spark.read.csv("/content/COLTIVAZIONE1(2).csv", header=True, inferSchema=True)
df.show(10)
# Out:
# +-----------------------+---------------+--------------------+----------------+--------------+-----------------+-----------+-------------------+------------+----------------------+---------+--------------------+---------------------+----------------------+----------------+--------------------+----------+---------+
# |comune_desc_sede_legale|cap_sede_legale|     ragione_sociale|  codice_fiscale|stato_attivita|codtipo_ruolo_ul1|art_com_tur|tipo_localizzazione|stato_att_ul|data_cessazione_ruolo1|ateco2007|toponimo_sede_legale|indirizzo_sede_legale|num_civico_sede_legale|prov_sede_legale|     des_attivita_ul|settorecna|unionecna|
# +-----------------------+---------------+--------------------+----------------+--------------+-----------------+-----------+-------------------+------------+----------------------+---------+--------------------+---------------------+----------------------+----------------+--------------------+----------+---------+
# ...

# %%
dfjoin.printSchema()
# Out:
# root
#  |-- codice_fiscale: string (nullable = true)
#  |-- comune_desc_sede_legale: string (nullable = true)
#  |-- cap_sede_legale: integer (nullable = true)
#  |-- ragione_sociale: string (nullable = true)
#  |-- stato_attivita: integer (nullable = true)
#  |-- codtipo_ruolo_ul1: string (nullable = true)
#  |-- art_com_tur: string (nullable = true)
#  |-- tipo_localizzazione: string (nullable = true)
#  |-- stato_att_ul: integer (nullable = true)
#  |-- data_cessazione_ruolo1: string (nullable = true)
#  |-- ateco2007: integer (nullable = true)
#  |-- toponimo_sede_legale: string (nullable = true)
#  |-- indirizzo_sede_legale: string (nullable = true)
#  |-- num_civico_sede_legale: string (nullable = true)
#  |-- prov_sede_legale: string (nullable = true)
#  |-- des_attivita_ul: string (nullable = true)
#  |-- settorecna: integer (nullable = true)
#  |-- unionecna: integer (nullable = true)
#  |-- comune_desc_sede_legale: string (nullable = true)
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- comune_desc_sede_legale: string (nullable = true)
#  |-- cap_sede_legale: integer (nullable = true)
#  |-- ragione_sociale: string (nullable = true)
#  |-- codice_fiscale: string (nullable = true)
#  |-- stato_attivita: integer (nullable = true)
#  |-- codtipo_ruolo_ul1: string (nullable = true)
#  |-- art_com_tur: string (nullable = true)
#  |-- tipo_localizzazione: string (nullable = true)
#  |-- stato_att_ul: integer (nullable = true)
#  |-- data_cessazione_ruolo1: string (nullable = true)
#  |-- ateco2007: integer (nullable = true)
#  |-- toponimo_sede_legale: string (nullable = true)
#  |-- indirizzo_sede_legale: string (nullable = true)
#  |-- num_civico_sede_legale: string (nullable = true)
#  |-- prov_sede_legale: string (nullable = true)
#  |-- des_attivita_ul: string (nullable = true)
#  |-- settorecna: integer (nullable = true)
#  |-- unionecna: integer (nullable = true)

# %%
dfjoin = df.join(df1, on=["codice_fiscale",'comune_desc_sede_legale','cap_sede_legale','ragione_sociale','codice_fiscale','stato_attivita','codtipo_ruolo_ul1','art_com_tur','tipo_localizzazione','stato_att_ul','ateco2007','toponimo_sede_legale','indirizzo_sede_legale','num_civico_sede_legale','prov_sede_legale','des_attivita_ul','settorecna','unionecna'], how="full")
dfjoin.show()
# Out:
# +----------------+-----------------------+---------------+--------------------+----------------+--------------+-----------------+-----------+-------------------+------------+---------+--------------------+---------------------+----------------------+----------------+--------------------+----------+---------+----------------------+----------------------+
# |  codice_fiscale|comune_desc_sede_legale|cap_sede_legale|     ragione_sociale|  codice_fiscale|stato_attivita|codtipo_ruolo_ul1|art_com_tur|tipo_localizzazione|stato_att_ul|ateco2007|toponimo_sede_legale|indirizzo_sede_legale|num_civico_sede_legale|prov_sede_legale|     des_attivita_ul|settorecna|unionecna|data_cessazione_ruolo1|data_cessazione_ruolo1|
# ...

# %%
dfjoin.where(df.comune_desc_sede_legale=='RONCIGLIONE').limit(10)
# Out:
# +----------------+-----------------------+---------------+--------------------+----------------+--------------+-----------------+-----------+-------------------+------------+---------+--------------------+---------------------+----------------------+----------------+--------------------+----------+---------+----------------------+----------------------+
# |  codice_fiscale|comune_desc_sede_legale|cap_sede_legale|     ragione_sociale|  codice_fiscale|stato_attivita|codtipo_ruolo_ul1|art_com_tur|tipo_localizzazione|stato_att_ul|ateco2007|toponimo_sede_legale|indirizzo_sede_legale|num_civico_sede_legale|prov_sede_legale|     des_attivita_ul|settorecna|unionecna|data_cessazione_ruolo1|data_cessazione_ruolo1|
# ...

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop3.2"

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://archive.apache.org/dist/spark/spark-3.1.1/spark-3.1.1-bin-hadoop3.2.tgz
# !tar xf spark-3.1.1-bin-hadoop3.2.tgz
# !pip install -q findspark
